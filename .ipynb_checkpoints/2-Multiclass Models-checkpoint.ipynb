# %% [markdown]
# # Kaggle Competition: MultiClass classification

# %% [markdown]
# <img src="https://octodex.github.com/images/octocat-de-los-muertos.jpg" alt="Cat" title="Cat" width="350" height="200" />
# *(image from octodex github)*

# %% [markdown]
# **We will first use the dataset training, metadata image and sentiment data to predict the Adoption Speed**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# LightGBM
import lightgbm as lgb

# Load scikit's classifier library
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold,RandomizedSearchCV


from sklearn.metrics import cohen_kappa_score, accuracy_score, confusion_matrix, f1_score

from xgboost import XGBClassifier, plot_importance

# %% [markdown]
# ## Data Preparation

# %%
#Load Data
train =pd.read_csv(r'C:\Users\alorenzodebrionne\Documents\Kaggle\Pet.My\train_features.csv',index_col=0)

# %%
train.columns
# Out:
# Index(['Quantity', 'Fee', 'VideoAmt', 'PetID', 'PhotoAmt', 'AdoptionSpeed',
#        'sentiment_document_score', 'sentiment_document_magnitude',
#        'metadata_topicality_max', 'metadata_topicality_mean',
#        'metadata_topicality_min', 'metadata_topicality_0_mean',
#        'metadata_topicality_0_max', 'metadata_topicality_0_min',
#        'L_metadata_0_cat_sum', 'L_metadata_0_dog_sum',
#        'L_metadata_any_cat_sum', 'L_metadata_any_dog_sum',
#        'metadata_color_pixelfrac_mean', 'metadata_color_pixelfrac_min',
#        'metadata_color_pixelfrac_max', 'metadata_color_score_mean',
#        'metadata_color_score_min', 'metadata_color_score_max', 'pixel_mean',
#        'blur_mean', 'pixel_min', 'blur_min', 'pixel_max', 'blur_max',
#        'pixel_sum', 'blur_sum', 'L_Color1', 'L_Color2', 'L_Color3', 'L_Breed1',
#        'L_Breed2', 'L_Name_missing', 'Name_Length', 'Description_Length',
#        'L_Fee_Free', 'N_pets_total', 'L_NoPhoto', 'L_NoVideo', 'Log_Age',
#        'L_scoreneg', 'State_Johor', 'State_Kedah', 'State_Kelantan',
#        'State_Kuala Lumpur', 'State_Labuan', 'State_Melaka',
#        'State_Negeri Sembilan', 'State_Pahang', 'State_Perak',
#        'State_Pulau Pinang', 'State_Sabah', 'State_Sarawak', 'State_Selangor',
#        'State_Terengganu', 'ColorName1_Black', 'ColorName1_Brown',
#        'ColorName1_Cream', 'ColorName1_Golden', 'ColorName1_Gray',
#        'ColorName1_White', 'ColorName1_Yellow', 'ColorName2_Brown',
#        'ColorName2_Cream', 'ColorName2_Golden', 'ColorName2_Gray',
#        'ColorName2_No Color', 'ColorName2_White', 'ColorName2_Yellow',
#        'Health_1', 'Health_2', 'Health_3', 'Gender_1', 'Gender_2', 'Gender_3',
#        'Dewormed_1', 'Dewormed_2', 'Dewormed_3', 'Type_1', 'Type_2',
#        'MaturitySize_1', 'MaturitySize_2', 'MaturitySize_3', 'MaturitySize_4',
#        'Sterilized_1', 'Sterilized_2', 'Sterilized_3', 'Vaccinated_1',
#        'Vaccinated_2', 'Vaccinated_3', 'FurLength_1', 'FurLength_2',
#        'FurLength_3'],
#       dtype='object')

# %% [markdown]
# ## Train/Test/Validation Sets

# %% [markdown]
# We are going to use 80% of the data for training and the remaining 20% to test the model.
# We will tune the hyperparameters using cross validation datasets.

# %%
#Extracting Features and Output
ids=train[['PetID']]
train_analysis=train.drop(['PetID'],axis=1)

X, y = train_analysis.loc[:, train_analysis.columns != 'AdoptionSpeed'], train_analysis['AdoptionSpeed']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)
#X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
plt.subplot(1, 2, 1)
prob_train  =y_train.value_counts(normalize=True)
prob_train.plot(kind='barh',figsize =(20,6))
plt.title('Adoption Speed Repartition for the Training Set (80% Data)')
plt.subplot(1, 2, 2)

prob  =y_test.value_counts(normalize=True)
prob.plot(kind='barh', figsize =(20,8))
plt.title('Adoption Speed Repartition for the Test Set (20% Data)')
plt.show()

# %%
print(len(train_analysis.columns))
# Out:
# 95

# %% [markdown]
# ## Features Selection

# %% [markdown]
# Select the features by examining only the training set and avoid overfitting (using XGboost)

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
# plot feature importance

fig, ax = plt.subplots(1,1,figsize=(12,15))
plot_importance(model, ax=ax )
plt.show()

# %% [markdown]
# ## Modelisation

# %% [markdown]
# In a first step we divide our data into a training(80% of Data) and a testing set (20% of Data). To tune the hyperparameter and avoid overfitting we used the technique of Cross Validation (CV). For K-Fold CV, we further split our training set into K number of subsets, called folds.We then iteratively fit the model K times, each time training the data on K-1 of the folds and evaluating on the Kth fold. For hyperparameter tuning, we perform many iterations of the entire K-Fold CV process, each time using different model settings. We then compare all of the models, select the best one! At the very end of training, we average the performance on each of the folds to come up with final validation metrics for the model.

# %% [markdown]
# <img src="https://i.imgur.com/amekoez.jpg" alt="Cat" title="Cat" width="800" height="600" />

# %% [markdown]
# ### Evaluation with Cohen Kappa measure

# %%
def evaluate(model, test_features, test_labels, pred):
  
    if pred ==1:
        predictions = model.predict(test_features)
   
    cohen_kappa= cohen_kappa_score(test_labels, predictions)
    accuracy=accuracy_score(test_labels,predictions)
    f1=f1_score(y_test,predictions,average='micro')
    
    #Confusion Matrix
    cm = confusion_matrix(test_labels, predictions)
    plt.figure(figsize=(20,6))
    
    sns.heatmap(cm, annot=True)
    plt.title('Confusion matrix')
    plt.figure(figsize = (5,4))
    plt.show()
    #Evaluation Metrics
    print('Cohen Kappa: {:0.2f}.'.format(cohen_kappa))
    print('Accuracy Score: {:0.2f}%.'.format(accuracy))
    print('F1 Score: {:0.2f}%.'.format(f1))

# %% [markdown]
# ## Random Forest

# %% [markdown]
# This will try out 3 X 2 X 4 X 3 X 2 X 1 = **144 combinations of settings!**

# %%
gridParams = {'min_samples_split': [2],
                      'min_samples_leaf': [ 3],
                      'max_depth': [10],
                      'max_features':[12],
                      'n_estimators': [100],
                      'class_weight':[{0: w} for w in [5,6]]}

print(gridParams)
# Out:
# {'min_samples_split': [2], 'n_estimators': [100], 'max_depth': [10], 'class_weight': [{0: 5}, {0: 6}], 'min_samples_leaf': [3], 'max_features': [12]}

# %%
# Use the random grid to search for best hyperparameters
rf = RandomForestClassifier()

# Random search of parameters, using 5 fold cross validation, 
rf_random = GridSearchCV( rf, gridParams, cv=StratifiedKFold(n_splits  =5),refit=True, verbose=0)


# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#        error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'min_samples_split': [2], 'n_estimators': [100], 'max_depth': [10], 'class_weight': [{0: 5}, {0: 6}], 'min_samples_leaf': [3], 'max_features': [12]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
rf_random.best_params_
# Out:
# {'class_weight': {0: 5},
#  'max_depth': 10,
#  'max_features': 14,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 100}

# %%
best_random = rf_random.best_estimator_
random_accuracy = evaluate(best_random, X_test, y_test,pred=1)
# Out:
# Cohen Kappa: 0.23.
# Accuracy Score: 0.43%.
# F1 Score: 0.43%.

# %% [markdown]
# ## XGBoost

# %% [markdown]
# More information on parameters tuning in: https://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/

# %%
n_estimators = [100]
learning_rate = [0.1]
max_depth =[10]
colsample_bytree=[0.3]

# Create the random grid
gridParams = {'n_estimators': n_estimators,
               'learning_rate': learning_rate,
               'max_depth': max_depth,
               'colsample_bytree': colsample_bytree,
               'class_weight':[{0: w} for w in [5,6]]}

# %%
from xgboost.sklearn import XGBClassifier

xgb1 = XGBClassifier()

clf = GridSearchCV(xgb1, gridParams,
                   cv=StratifiedKFold(n_splits  =5), 
                   refit=True, verbose=0)

# Fit the random search model
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#        error_score='raise-deprecating',
#        estimator=XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'class_weight': [{0: 5}, {0: 6}], 'max_depth': [10], 'colsample_bytree': [0.3], 'n_estimators': [100], 'learning_rate': [0.1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'colsample_bytree': 0.3,
#  'learning_rate': 0.7,
#  'max_depth': 4,
#  'n_estimators': 100}

# %%
best_xgb = clf.best_estimator_
xgb_accuracy = evaluate(best_xgb, X_test, y_test,1)
# Out:
# Cohen Kappa: 0.24.
# Accuracy Score: 0.43%.
# F1 Score: 0.43%.

# %% [markdown]
# ## Decision Tree Classifier

# %%
criterion =['gini','entropy']

max_depth =[3,4,5]
min_samples_leaf  = [2,3,4]

# Create the random grid
gridParams = {'criterion': criterion,
               'min_samples_leaf': min_samples_leaf,
               'max_depth': max_depth}

# %%
dt = DecisionTreeClassifier()

dt_cv = GridSearchCV(dt, gridParams,
                   cv=StratifiedKFold(n_splits  =5), 
                   refit=True, verbose=0)

# Fit the random search model
dt_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] criterion=gini, max_depth=3, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=2 .................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=3, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=4, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=4, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=2 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=2, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=3 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=3, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=4, total=   0.0s
# [CV] criterion=gini, max_depth=5, min_samples_leaf=4 .................
# [CV] .. criterion=gini, max_depth=5, min_samples_leaf=4, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=2, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=3, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=entropy, max_depth=3, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=3, min_samples_leaf=4, total=   0.0s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=4, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=4, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=2 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=2, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=3 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=3, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=4, total=   0.1s
# [CV] criterion=entropy, max_depth=5, min_samples_leaf=4 ..............
# [CV]  criterion=entropy, max_depth=5, min_samples_leaf=4, total=   0.1s
# [Parallel(n_jobs=1)]: Done  90 out of  90 | elapsed:   14.3s finished
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#        error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['gini', 'entropy'], 'min_samples_leaf': [2, 3, 4], 'max_depth': [3, 4, 5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
best_dt = dt_cv.best_estimator_
dt_accuracy = evaluate(best_dt, X_test, y_test)
# Out:
# Cohen Kappa: 0.17.
# Accuracy Score: 0.38%.
# F1 Score: 0.38%.

# %% [markdown]
# ## LightGBM

# %%
# Create parameters to search
gridParams = {
    'learning_rate': [0.1],
    'n_estimators': [50],
    'num_leaves': [12],
    'boosting_type' : ['gbdt'],
    'objective' : ['multiclass'],
    'random_state' : [501], # Updated from 'seed'
    'colsample_bytree' : [0.65,],
    'subsample' : [0.7],
    'reg_alpha' : [1],
    'reg_lambda' : [1.2],
    'class_weight':{0: 5} }

# Create classifier to use. Note that parameters have to be input manually
# not as a dict!
mdl = lgb.LGBMClassifier()

# To view the default model params:
mdl.get_params().keys()
# Out:
# dict_keys(['silent', 'objective', 'min_child_weight', 'learning_rate', 'class_weight', 'reg_alpha', 'subsample_for_bin', 'colsample_bytree', 'random_state', 'n_jobs', 'min_split_gain', 'importance_type', 'max_depth', 'boosting_type', 'min_child_samples', 'num_leaves', 'n_estimators', 'subsample_freq', 'subsample', 'reg_lambda'])

# %%
lgb_cv = GridSearchCV(mdl, gridParams,
                   cv=StratifiedKFold(n_splits  =5), 
                   refit=True, verbose=2)

# Fit the random search model
lgb_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.2s remaining:    0.0s
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=6, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   0.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.005, class_weight={0: 5}, num_leaves=8, reg_alpha=1.2, colsample_bytree=0.65, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.0s
# ...
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1, total=   3.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2, total=   4.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2, total=   4.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2, total=   4.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2, total=   3.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.2, total=   2.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2, total=   2.5s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2, total=   2.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2, total=   2.1s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2, total=   2.0s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.2, total=   1.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.8s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.9s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.5s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.7, random_state=501, reg_lambda=1.4, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.3s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [CV] objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4
# [CV]  objective=multiclass, n_estimators=50, boosting_type=gbdt, learning_rate=0.1, class_weight={0: 8}, num_leaves=16, reg_alpha=1.2, colsample_bytree=0.66, subsample=0.75, random_state=501, reg_lambda=1.4, total=   1.4s
# [Parallel(n_jobs=1)]: Done 5760 out of 5760 | elapsed: 181.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=None, shuffle=False),
#        error_score='raise-deprecating',
#        estimator=LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#         importance_type='split', learning_rate=0.1, max_depth=-1,
#         min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#         n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#         random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'objective': ['multiclass'], 'class_weight': [{0: 5}, {0: 6}, {0: 7}, {0: 8}], 'n_estimators': [50], 'boosting_type': ['gbdt'], 'learning_rate': [0.005, 0.05, 0.1], 'reg_lambda': [1, 1.2, 1.4], 'num_leaves': [6, 8, 12, 16], 'reg_alpha': [1, 1.2], 'colsample_bytree': [0.65, 0.66], 'subsample': [0.7, 0.75], 'random_state': [501]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=2)

# %%
lgb_cv.best_params_
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': {0: 5},
#  'colsample_bytree': 0.65,
#  'learning_rate': 0.1,
#  'n_estimators': 50,
#  'num_leaves': 16,
#  'objective': 'multiclass',
#  'random_state': 501,
#  'reg_alpha': 1,
#  'reg_lambda': 1.2,
#  'subsample': 0.7}

# %%
best_lgb = lgb_cv.best_estimator_
dt_accuracy = evaluate(best_lgb, X_test, y_test,1)
# Out:
# Cohen Kappa: 0.22.
# Accuracy Score: 0.42%.
# F1 Score: 0.42%.

# %%
y_pred = pd.DataFrame() 
.
y_pred['predictions'] = lgb_cv.predict(X_test)

y_pred =pd.concat([y_pred,pd.DataFrame(lgb_cv.predict_proba(X_test))], axis=1)

# %% [markdown]
# ## Stacking predictions
